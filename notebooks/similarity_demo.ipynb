# %% [markdown]
# # Portrait Similarity Retrieval (Task 2)
#
# This notebook demonstrates a similarity retrieval system built on the NGA dataset using weak supervision and triplet loss.
#
# We evaluate the system using Precision@K and mAP, and show qualitative retrieval examples.

# %%
import os
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset
#
# We use a subset of the NGA dataset (~200 portraits).
# Artist metadata is used for weak supervision.

# %%
df = pd.read_csv('data/processed/portrait_subset.csv')
print('Total images:', len(df))
df.head()

# %% [markdown]
# ## Method
#
# Triplet loss + weak supervision (artist labels).
# Combined features: full image + face-aware (MediaPipe).

# %% [markdown]
# ## Quantitative Results

# %%
with open('outputs/eval_results_vit_combined.txt') as f:
    print(f.read())

# %% [markdown]
# ## Qualitative Examples

# %%
def show_result(p):
    img = Image.open(p)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

show_result('outputs/result_vit_combined_painting_171260.png')
show_result('outputs/result_vit_combined_painting_34146.png')
show_result('outputs/result_vit_combined_painting_42485.png')

# %% [markdown]
# ## Observations
#
# - strong same-artist clustering
# - good stylistic grouping
# - pose sometimes works
# - fails on cross-domain cases

# %% [markdown]
# ## Conclusion
#
# Meaningful retrieval despite weak supervision.
# Future: more data, better face modeling.
